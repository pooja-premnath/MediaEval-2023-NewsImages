# %%
import pandas as pd


file_path = r'C:\Users\pooja\Documents\GitHub\MediaEval\GDELT-Dataset\GDELT-P1-Training.txt'
training_df = pd.read_csv(file_path, delimiter='\t')

# %%
training_df.head()
# Out:
#           # article                aid
# 0  2023071921004530   20230719210000-4  \
# 1  2023071921008450   20230719210000-5
# 2  2023071921009100   20230719210000-6
# 3  2023071921000440   20230719210000-8
# 4  2023071921008590  20230719210000-16
#
#                                                  url
# 0  https://www.rfdtv.com/helena-agri-enterprises-...  \
# 1  https://943wsc.iheart.com/content/2023-07-19-n...
# 2  https://kowb1290.com/laramie-rangers-play-fina...
# 3  https://www.mapleridgenews.com/news/undesired-...
# 4  https://www.fourfourtwo.com/news/why-england-c...
#
#                                                  img
# 0  https://cdn.jwplayer.com/v2/media/0aHC9TAX/thu...  \
# 1  https://i.iheart.com/v3/re/new_assets/64b2fed5...
# 2  https://townsquare.media/site/106/files/2023/0...
# 3  https://www.mapleridgenews.com/wp-content/uplo...
# 4  https://cdn.mos.cms.futurecdn.net/3xNoemnubE8u...
#
#                                 iid          hashvalue
# ...

# %%
file_path = r"C:\Users\pooja\Documents\GitHub\MediaEval\GDELT-Dataset\GDELT-P1-Test-Text.txt"
test_df = pd.read_csv(file_path, delimiter='\t')

# %%
test_df.head()
# Out:
#           # article                 aid
# 0  2023072008159070  20230720081500-229  \
# 1  2023072008150400  20230720081500-236
# 2  2023072008152580  20230720081500-239
# 3  2023072008155940  20230720081500-247
# 4  2023072008152680  20230720081500-261
#
#                                                  url  img  iid
# 0  https://www.theaustralian.com.au/news/latest-n...  NaN  NaN  \
# 1  https://asianews.network/vietnams-cities-to-be...  NaN  NaN
# 2  https://www.telegraphindia.com/feeds/world/gun...  NaN  NaN
# 3  https://www.insidermonkey.com/blog/meta-platfo...  NaN  NaN
# 4  https://timesofoman.com/article/133710-german-...  NaN  NaN
#
#             hashvalue                                              title
# 0  20230720081500-229  Xi hails 'old friend' Kissinger in Beijing mee...  \
# 1  20230720081500-236  Vietnam's cities to become hubs for internatio...
# 2  20230720081500-239  World Cup | Gunman kills 2 people hours ahead ...
# ...

# %%
file_path = r"C:\Users\pooja\Documents\GitHub\MediaEval\GDELT-Dataset\GDELT-P1-Test-Img.txt"
test_image_df = pd.read_csv(file_path, delimiter='\t')

# %%
test_image_df.head()
# Out:
#    # article  aid  url                                                img
# 0        NaN  NaN  NaN  https://s.yimg.com/ny/api/res/1.2/VxHC9of3z5Rx...  \
# 1        NaN  NaN  NaN  https://www.eyeradio.org/wp-content/uploads/20...
# 2        NaN  NaN  NaN  https://1075914428.rsc.cdn77.org/data/images/f...
# 3        NaN  NaN  NaN  https://c.ndtvimg.com/2023-07/p5fat6ko_couple-...
# 4        NaN  NaN  NaN  https://i0.wp.com/citynews.com.au/wp-content/u...
#
#                                 iid  hashvalue  title  text
# 0  00162BE35B3D9EF9C2F9D9C4910AD9C7        NaN    NaN   NaN  \
# 1  0041A6587EECDDC8C4504ECF5E64E419        NaN    NaN   NaN
# 2  00651CC41AFF4FBB2AA06CF736A44B2F        NaN    NaN   NaN
# 3  0068DF73DF5FB553681181EE2AB11311        NaN    NaN   NaN
# 4  006B5D2697DD4B0F21792C71762A019D        NaN    NaN   NaN
#
#                                 imgFile  Date
# 0  00162BE35B3D9EF9C2F9D9C4910AD9C7.jpg   NaN
# 1  0041A6587EECDDC8C4504ECF5E64E419.jpg   NaN
# ...

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'https?://\S+', '', text)
    words = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    ps = PorterStemmer()
    words = [ps.stem(word) for word in words]
    text = ' '.join(words)
    return text

# Create a new DataFrame with preprocessed 'url,' 'title,' and 'text' columns
preprocessed_df = pd.DataFrame({
    'url': training_df['url'].apply(preprocess_text),
    'title': training_df['title'].apply(preprocess_text),
    'text': training_df['text'].apply(preprocess_text)
})

# Print the new DataFrame
print(preprocessed_df)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[10], line 14
#      10     return text
#      12 # Create a new DataFrame with preprocessed 'url,' 'title,' and 'text' columns
#      13 preprocessed_df = pd.DataFrame({
# ---> 14     'url': training_df['url'].apply(preprocess_text),
#      15     'title': training_df['title'].apply(preprocess_text),
#      16     'text': training_df['text'].apply(preprocess_text)
#      17 })
#      19 # Print the new DataFrame
#      20 print(preprocessed_df)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4626, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4516 def apply(
#    4517     self,
#    4518     func: AggFuncType,
#    (...)
#    4521     **kwargs,
#    4522 ) -> DataFrame | Series:
#    4523     """
#    4524     Invoke function on values of Series.
#    4525
# ...
